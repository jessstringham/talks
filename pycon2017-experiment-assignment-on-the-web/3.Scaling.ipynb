# %% [markdown]
# # Scaling
#
# We have our first implementation! I can use this to run one experiment.
#
# Now let's look at running more than one experiment at a time. First, I'll generalize my rules a bit:
#
# * ① Given an experimental unit, return the value of the variant to show
# * ② The same experimental unit is assigned to the same variant
# * ③ Different experimental units are randomly assigned
# * ④ The proportion of experimental units assigned to each variant is the proper proportion.
#
# Now I'll run two experiments:
# * The color experiment with an experimental unit of user_id and proportion of 50% red and 50% blue.
# * The size experiment with an experimental unit of user_id and proportion of 50% big and 50% small.
#
# There are a few approaches I can take for scaling.
#
# - **Scheduling**: Coordinate with whoever is running the other experiment, and only run one at a time.
# - **Independent**: Pretend the other experiment doesn't exist and treat its effects as another unknown variable.
# - **Splitting traffic**: Split traffic between experiments. I won't demonstrate that in these notebooks, but the idea is taking the assignment groups introduced in [4.Rollout](4.Rollout.html), and use them to divide traffic between experiments.
#
#
# Picturing the last two:
# ![two experiments](files/2experiments.png)
#
# ![split traffic](files/split-traffic.png)

# %%
import pandas as pd

from utils import spoilers
from utils.pretty import pp
from utils.simulate import n_different_users

# %% [markdown]
# ## Independent experiments
#
# I'll use an example of independent experiments. I'll implement a `choose_size_assignment` a lot like the `choose_color_assignment`.

# %%
def choose_color_assignment(user_id):
    key = "{}|color".format(user_id)    
    assignment_i = spoilers.hash_func(key) % 2
    return ['red', 'blue'][assignment_i]

def choose_size_assignment(user_id):
    key = "{}|size".format(user_id)    
    assignment_i = spoilers.hash_func(key) % 2
    return ['big', 'small'][assignment_i]

# %% [markdown]
# This is the same function from last time, which I already showed completed the goals. I do want to show that these are independent.
#
# ## `user_id`s assignments to the size and color experiments are independent
#
# I'll look at a few user assignments, and compare how they were assinged to the color and size experiments.
#
# I'll see the color assignment doesn't influence the size assignment.

# %%
pp(
    pd.merge(
        n_different_users(choose_color_assignment, n=20), 
        n_different_users(choose_size_assignment, n=20, key='size'), 
        on='user_id'
    )
)
# Out:
# <style  type="text/css" >
#     #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row0_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row0_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row1_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row1_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row2_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row2_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row3_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row3_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row4_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row4_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row5_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row5_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row6_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row6_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row7_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row7_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row8_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row8_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row9_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row9_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row10_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row10_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row11_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row11_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row12_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row12_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row13_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row13_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row14_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row14_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row15_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row15_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row16_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row16_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row17_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row17_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row18_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row18_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row19_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row19_col2 {
#             color:  black;
#              background-color:  black;
#         }</style>
# <table id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >user_id</th>
#         <th class="col_heading level0 col1" >color</th>
#         <th class="col_heading level0 col2" >size</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2" class="row_heading level0 row0" >0</th>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row0_col0" class="data row0 col0" >0</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row0_col1" class="data row0 col1" >blue</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row0_col2" class="data row0 col2" >big</td>
#     </tr>    <tr>
#         <th id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2" class="row_heading level0 row1" >1</th>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row1_col0" class="data row1 col0" >1</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row1_col1" class="data row1 col1" >blue</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row1_col2" class="data row1 col2" >big</td>
#     </tr>    <tr>
#         <th id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2" class="row_heading level0 row2" >2</th>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row2_col0" class="data row2 col0" >2</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row2_col1" class="data row2 col1" >red</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row2_col2" class="data row2 col2" >small</td>
#     </tr>    <tr>
#         <th id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2" class="row_heading level0 row3" >3</th>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row3_col0" class="data row3 col0" >3</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row3_col1" class="data row3 col1" >blue</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row3_col2" class="data row3 col2" >small</td>
#     </tr>    <tr>
#         <th id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2" class="row_heading level0 row4" >4</th>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row4_col0" class="data row4 col0" >4</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row4_col1" class="data row4 col1" >blue</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row4_col2" class="data row4 col2" >small</td>
#     </tr>    <tr>
#         <th id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2" class="row_heading level0 row5" >5</th>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row5_col0" class="data row5 col0" >5</td>
#         <td id="T_c0a4224a_3c4d_11e7_94e3_109add6da4a2row5_col1" class="data row5 col1" >blue</td>

# %% [markdown]
# If I look at a bunch of users, 25% of users should end up seeing each combination.

# %%
pd.merge(
        n_different_users(choose_color_assignment, n=10000), 
        n_different_users(choose_size_assignment, n=10000, key='size'), 
        on='user_id'
    ).groupby(['color', 'size']).count()
# Out:
#              user_id
# color size
# blue  big       2480
#       small     2524
# red   big       2504
#       small     2492

# %% [markdown]
# ## Independence done wrong
#
# I haven't shown a bad example for a while. Let's see what happens if I forget to update the salt for the size experiment.
#
# `bad_choose_size_assignment` uses the same salt as `choose_color_assignment`.

# %%
def bad_choose_size_assignment(user_id):
    key = "{}|color".format(user_id)    
    assignment_i = spoilers.hash_func(key) % 2
    return ['big', 'small'][assignment_i]

# %%
pp(
    pd.merge(
        n_different_users(choose_color_assignment, n=100), 
        n_different_users(bad_choose_size_assignment, n=100, key='size'), 
        on='user_id'
    )
)
# Out:
# <style  type="text/css" >
#     #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row0_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row0_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row1_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row1_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row2_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row2_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row3_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row3_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row4_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row4_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row5_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row5_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row6_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row6_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row7_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row7_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row8_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row8_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row9_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row9_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row10_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row10_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row11_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row11_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row12_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row12_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row13_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row13_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row14_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row14_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row15_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row15_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row16_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row16_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row17_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row17_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row18_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row18_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row19_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row19_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row20_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row20_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row21_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row21_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row22_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row22_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row23_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row23_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row24_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row24_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row25_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row25_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row26_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row26_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row27_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row27_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row28_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row28_col2 {
#             color:  orange;
#              background-color:  orange;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row29_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row29_col2 {
#             color:  black;
#              background-color:  black;
#         }    #T_c0e7ff50_3c4d_11e7_8255_109add6da4a2row30_col1 {
#             color:  red;
#              ba

# %% [markdown]
# Awkward! The assignment in the color experiments is completely dependent on the assignment in the size experiment!

# %%
pd.merge(
        n_different_users(choose_color_assignment, n=10000), 
        n_different_users(bad_choose_size_assignment, n=10000, key='size'), 
        on='user_id'
    ).groupby(['color', 'size']).count()
# Out:
#              user_id
# color size
# blue  small     5004
# red   big       4996

# %% [markdown]
# # Summary
#
# This talked about a few ways to run more than one experiment at a time, and showed how salts can be used to shuffle users, which is useful for running independent experiments.
#
# Dependent assignments is fun example: it's when assignment betrays and makes super dependent experiments! I might think I can analyze them independently, but I'd be getting the wrong results!
#
#
# # [Next: Rollout](4.Rollout.ipynb)
#
# With experiment rollout, we can gradually roll out new features.

# %% [markdown]
# # TOC
# - **[0. Introduction](0.Introduction.ipynb)**: What a good `choose_color_assignment` function looks like.
# - **[1. Experimental Units](1.ExperimentalUnits.ipynb)**: What happens when I don't pay attention to experimental units.
# - **[2. Deterministic Assignment](2.DeterministicAssignment.ipynb)**: What it looks like to deterministically assign
# - **[3. Scaling](3.Scaling.ipynb)**: How not to run two experiments at the same time.
# - **[4. Rollout](4.Rollout.ipynb)**: How to gradually show users a new experiment.
