# %% [markdown]
# # Deterministic Assignment
#
# Depending on the use case, a deterministic function might make sense. An advantage is that it won't need a database or network call before it can start rendering the variant. That's great for an assignment that needs to happen before a network request, like as soon as a mobile app starts up.
#
# Just like before, there are four things we should keep an eye out for:
#
# * ① Given a user_id, return the string of the color to show
# * ② The same user_id is assigned to the same color
# * ③ Different user_ids are randomly assigned
# * ④ The proportion of user_ids that see red and blue is roughly 50-50

# %%
import hashlib

from utils.simulate import n_different_users
from utils.simulate import same_user_n_times
from utils.spoilers import spoiler_hash_func
from utils.pretty import pp

# %% [markdown]
# ## Outline
#
# Here's the function that I'll use. I'll define the hash function later on.

# %%
def half_spoiler_choose_color_assignment(user_id):
    # I'll use a string with the experimental unit, and an experiment salt, "color".
    key = "{}|color".format(user_id)
    
    # Then I'll use a hash function. This one takes a string and returns an int.
    # Then I'll % 2 it to get a 0 or a 1
    assignment_i = spoiler_hash_func(key) % 2
    # And use that to index into an array of assignments
    return ['red', 'blue'][assignment_i]

# %% [markdown]
# This function takes care of ① for us.
#
# ### ① Given a user_id, return the string of the color to show ✅
#
# The other functions in this notebook use the same outline, so I'll just show this once:

# %%
half_spoiler_choose_color_assignment(user_id=1)
# Out:
# 'blue'

# %% [markdown]
# ## Picking a `hash_func`
#
# `hash_func` needs to help with the other three goals:
#
# * ② The same user_id is assigned to the same color
# * ③ Different user_ids are randomly assigned
# * ④ The proportion of user_ids that see red and blue is roughly 50-50
#
#
# ### Bad hash function
#
# Here's a bad version:

# %%
def bad_hash_func(input_str):
    return len(input_str)

# This is the same as the code before, but with a different name and hash function.
def bad_choose_color_assignment(user_id):
    key = "{}|color".format(user_id)    
    assignment_i = bad_hash_func(key) % 2
    return ['red', 'blue'][assignment_i]

# %% [markdown]
# ###  ② The same user_id is assigned to the same color ✅

# %%
pp(
    same_user_n_times(bad_choose_color_assignment, n=10)
)
# Out:
# <style  type="text/css" >
#     #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row0_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row1_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row2_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row3_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row4_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row5_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row6_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row7_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row8_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row9_col1 {
#             color:  blue;
#              background-color:  blue;
#         }</style>
# <table id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >user_id</th>
#         <th class="col_heading level0 col1" >color</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row0" >0</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row0_col0" class="data row0 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row0_col1" class="data row0 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row1" >1</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row1_col0" class="data row1 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row1_col1" class="data row1 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row2" >2</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row2_col0" class="data row2 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row2_col1" class="data row2 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row3" >3</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row3_col0" class="data row3 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row3_col1" class="data row3 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row4" >4</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row4_col0" class="data row4 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row4_col1" class="data row4 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row5" >5</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row5_col0" class="data row5 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row5_col1" class="data row5 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row6" >6</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row6_col0" class="data row6 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row6_col1" class="data row6 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row7" >7</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row7_col0" class="data row7 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row7_col1" class="data row7 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row8" >8</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row8_col0" class="data row8 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row8_col1" class="data row8 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2" class="row_heading level0 row9" >9</th>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row9_col0" class="data row9 col0" >1</td>
#         <td id="T_c8d3955c_3c4c_11e7_9e86_109add6da4a2row9_col1" class="data row9 col1" >blue</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### ③ Different `user_id`s are randomly assigned ❌
#
# When we look at different `user_id`s, it doesn't look very random.
#
# Specifically, similar `user_id`s are assigned to the same thing. This could lead to bias, like if `user_id`s are assigned incrementally!

# %%
pp(
    n_different_users(bad_choose_color_assignment, n=30)
)
# Out:
# <style  type="text/css" >
#     #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row0_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row1_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row2_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row3_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row4_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row5_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row6_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row7_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row8_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row9_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row10_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row11_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row12_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row13_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row14_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row15_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row16_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row17_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row18_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row19_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row20_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row21_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row22_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row23_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row24_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row25_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row26_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row27_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row28_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row29_col1 {
#             color:  red;
#              background-color:  red;
#         }</style>
# <table id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >user_id</th>
#         <th class="col_heading level0 col1" >color</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row0" >0</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row0_col0" class="data row0 col0" >0</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row0_col1" class="data row0 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row1" >1</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row1_col0" class="data row1 col0" >1</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row1_col1" class="data row1 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row2" >2</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row2_col0" class="data row2 col0" >2</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row2_col1" class="data row2 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row3" >3</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row3_col0" class="data row3 col0" >3</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row3_col1" class="data row3 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row4" >4</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row4_col0" class="data row4 col0" >4</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row4_col1" class="data row4 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row5" >5</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row5_col0" class="data row5 col0" >5</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row5_col1" class="data row5 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row6" >6</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row6_col0" class="data row6 col0" >6</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row6_col1" class="data row6 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row7" >7</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row7_col0" class="data row7 col0" >7</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row7_col1" class="data row7 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row8" >8</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row8_col0" class="data row8 col0" >8</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row8_col1" class="data row8 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row9" >9</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row9_col0" class="data row9 col0" >9</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row9_col1" class="data row9 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row10" >10</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row10_col0" class="data row10 col0" >10</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row10_col1" class="data row10 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2" class="row_heading level0 row11" >11</th>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row11_col0" class="data row11 col0" >11</td>
#         <td id="T_c8de39d2_3c4c_11e7_8b52_109add6da4a2row11_col1" class="data row11 col1" >red</td>
#     </tr>    <tr>
#         <th i

# %% [markdown]
# ### ④ The proportion of `user_id`s that see red and blue is roughly 50-50 ❌
#
# At this point, I'm already concerned about this function. But it's also nowhere near 50-50.

# %%
n_different_users(bad_choose_color_assignment, n=1000).groupby('color').count()
# Out:
#        user_id
# color
# blue       910
# red         90

# %% [markdown]
# ## `md5`
#
# I'm going to use `md5` for the hash function.
#
# If I give an input that differs just a tiny bit, it gives me a completely different number. It can be used to make statistically random assignments (Kohavi p165).

# %%
def hash_func(input_str):
    hash_hex = hashlib.md5(input_str.encode('utf-8')).hexdigest()
    return int(hash_hex[:15], 16)

def choose_color_assignment(user_id):
    key = "{}|color".format(user_id)    
    assignment_i = hash_func(key) % 2
    return ['red', 'blue'][assignment_i]

# %% [markdown]
# ###  ② The same user_id is assigned to the same color  ✅

# %%
same_user_n_times(choose_color_assignment, n=100).groupby('color').count()
# Out:
#        user_id
# color
# blue       100

# %% [markdown]
# ### ③ Different user_ids are randomly assigned ✅

# %%
pp(
    n_different_users(choose_color_assignment, n=150)
)
# Out:
# <style  type="text/css" >
#     #T_c90323b4_3c4c_11e7_a65a_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row0_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row1_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row2_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row3_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row4_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row5_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row6_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row7_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row8_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row9_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row10_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row11_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row12_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row13_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row14_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row15_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row16_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row17_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row18_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row19_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row20_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row21_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row22_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row23_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row24_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row25_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row26_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row27_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row28_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row29_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row30_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row31_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row32_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row33_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row34_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row35_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row36_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row37_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row38_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row39_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row40_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row41_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row42_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row43_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row44_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row45_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row46_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row47_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row48_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row49_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row50_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row51_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row52_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row53_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row54_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row55_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row56_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row57_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row58_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row59_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row60_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_c90323b4_3c4c_11e7_a65a_109add6da4a2row61_col1 {
#             color:

# %% [markdown]
# ### ④ The proportion of user_ids that see red and blue is roughly 50-50 ✅

# %%
n_different_users(choose_color_assignment, n=10000).groupby('color').count()
# Out:
#        user_id
# color
# blue      5004
# red       4996

# %% [markdown]
# # Summary
#
# This showed how to implement the assignment function deterministically by using a hash function.
#
# # [Next : 3. Scaling](3.Scaling.ipynb)
#
# This is the version of assignment I'll use. Now I'll extend it to support more than one experiment on the same users.

# %% [markdown]
# # TOC
# - **[0. Introduction](0.Introduction.ipynb)**: What a good `choose_color_assignment` function looks like.
# - **[1. Experimental Units](1.ExperimentalUnits.ipynb)**: What happens when I don't pay attention to experimental units.
# - **[2. Deterministic Assignment](2.DeterministicAssignment.ipynb)**: What it looks like to deterministically assign
# - **[3. Scaling](3.Scaling.ipynb)**: How not to run two experiments at the same time.
# - **[4. Rollout](4.Rollout.ipynb)**: How to gradually show users a new experiment.
