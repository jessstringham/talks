# %% [markdown]
# # Experiment rollout
#
# In the previous pages, I had two variants, so I split users into to two groups.
#
# It's often useful to split users (or whatever the experiment unit is!) into many groups and assign those to variants. Because users are randomly assigned to a group, the groups act like interchangeable representative cross-sections.
#
# This can be used for a couple of things:
# * Have different sized groups. Useful for rolling out an experiment in phases.
# * Split traffic between two experiments, so a user is shown only one of the experiments.
# * Limiting experimentation to a subset of users.
#
# Heads up, as I start showing things to assignment groups, I'll start to change them. If I show one assignment group a bad variant, they might no longer be a representative cross-section. Salts can help a little here by shuffling and reassigning groups.
#
# A lot of the more advanced experiment assignments depend on a combination of assignment groups.
#
#
# ## Example: Experiment rollout
#
# So far, I've been showing experiments with a 50-50 split.
#
# Now I have a situation where I don't want to show it to 50% of users right away. Instead, I want to start with 20% of users, and then move up to 50%. I also want to make it once someone starts seeing the new feature, I shouldn't take it away.
#
# Here are the rules again.
#
# * ① Given an experimental unit, return the value of the variant to show
# * ② The same experimental unit is assigned to the same variant
# * ③ Different experimental units are randomly assigned
# * ④ The proportion of experimental units assigned to each variant is the proper proportion.
#
# For ④, let's have the phase1 experiment show 20% of users blue, and phase 2 show 50%.
#
# * Ⓐ Devices that see blue in phase 1 should continue to see it in phase 2.
#
# | **Phase 1** |
# |-------------|
# | <img width=33% src="files/rollout-phase-1.png"> |
# | **Phase 2** |
# | <img width=33% src="files/rollout-phase-2.png"> |
#
# ### Disclaimers
#
# This way of doing experiment rollout might not be the best idea in all cases.
#
# I should make sure I have proper logging in place so I can tell which phase an assignment takes place.
#
# Also, when I do analysis, that 20% of users who were shown blue in phase 1 are now a little different than the 30% who saw red in phase 1 and blue in phase 2. I might want to analyze the 3 groups separately.

# %%
import pandas as pd

from utils import spoilers
from utils.pretty import pp
from utils.simulate import n_different_users
from utils.simulate import same_user_n_times

# %%
# Phase 2: 80-20
def choose_color_assignment_phase_1(user_id):
    key = "{}|color".format(user_id)
    slot = spoilers.hash_func(key) % 20
    if slot < 16:
        return 'red'
    else:
        return 'blue'


# Phase 2: 50-50
def choose_color_assignment_phase_2(user_id):
    key = "{}|color".format(user_id)
    slot = spoilers.hash_func(key) % 20
    if slot < 10:
        return 'red'
    else:
        return 'blue'

# %% [markdown]
# ### ① Given a user_id, return the string of the color to show

# %%
# Don't mind me. This prints the user id, and what it was assigned to in phase 1 and phase 2.
def phase_info(user_id):
    print("user_id:{}\tphase 1: {}\tphase 2: {}".format(
        user_id, 
        choose_color_assignment_phase_1(user_id=user_id), 
        choose_color_assignment_phase_2(user_id=user_id)))


# Let's look at a few
phase_info(1) # Stays in red
phase_info(2) # Moves from red to blue
phase_info(4) # Stays in blue
# Out:
# user_id:1	phase 1: red	phase 2: red
# user_id:2	phase 1: red	phase 2: blue
# user_id:4	phase 1: blue	phase 2: blue

# %% [markdown]
# ### ② The same user_id is assigned to the same color

# %%
pp(
    same_user_n_times(choose_color_assignment_phase_1, n=10, key='phase1')
)
# Out:
# <style  type="text/css" >
#     #T_b6104908_3cae_11e7_b637_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_b6104908_3cae_11e7_b637_109add6da4a2row0_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row1_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row2_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row3_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row4_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row5_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row6_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row7_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row8_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b6104908_3cae_11e7_b637_109add6da4a2row9_col1 {
#             color:  red;
#              background-color:  red;
#         }</style>
# <table id="T_b6104908_3cae_11e7_b637_109add6da4a2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >user_id</th>
#         <th class="col_heading level0 col1" >phase1</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row0" >0</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row0_col0" class="data row0 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row0_col1" class="data row0 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row1" >1</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row1_col0" class="data row1 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row1_col1" class="data row1 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row2" >2</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row2_col0" class="data row2 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row2_col1" class="data row2 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row3" >3</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row3_col0" class="data row3 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row3_col1" class="data row3 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row4" >4</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row4_col0" class="data row4 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row4_col1" class="data row4 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row5" >5</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row5_col0" class="data row5 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row5_col1" class="data row5 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row6" >6</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row6_col0" class="data row6 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row6_col1" class="data row6 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row7" >7</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row7_col0" class="data row7 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row7_col1" class="data row7 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row8" >8</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row8_col0" class="data row8 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row8_col1" class="data row8 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b6104908_3cae_11e7_b637_109add6da4a2" class="row_heading level0 row9" >9</th>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row9_col0" class="data row9 col0" >1</td>
#         <td id="T_b6104908_3cae_11e7_b637_109add6da4a2row9_col1" class="data row9 col1" >red</td>
#     </tr></tbody>
# </table>

# %%
pp(
    same_user_n_times(choose_color_assignment_phase_2, n=10)
)
# Out:
# <style  type="text/css" >
#     #T_b61807ec_3cae_11e7_8c51_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row0_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row1_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row2_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row3_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row4_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row5_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row6_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row7_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row8_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61807ec_3cae_11e7_8c51_109add6da4a2row9_col1 {
#             color:  red;
#              background-color:  red;
#         }</style>
# <table id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >user_id</th>
#         <th class="col_heading level0 col1" >color</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row0" >0</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row0_col0" class="data row0 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row0_col1" class="data row0 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row1" >1</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row1_col0" class="data row1 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row1_col1" class="data row1 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row2" >2</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row2_col0" class="data row2 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row2_col1" class="data row2 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row3" >3</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row3_col0" class="data row3 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row3_col1" class="data row3 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row4" >4</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row4_col0" class="data row4 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row4_col1" class="data row4 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row5" >5</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row5_col0" class="data row5 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row5_col1" class="data row5 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row6" >6</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row6_col0" class="data row6 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row6_col1" class="data row6 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row7" >7</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row7_col0" class="data row7 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row7_col1" class="data row7 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row8" >8</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row8_col0" class="data row8 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row8_col1" class="data row8 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61807ec_3cae_11e7_8c51_109add6da4a2" class="row_heading level0 row9" >9</th>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row9_col0" class="data row9 col0" >1</td>
#         <td id="T_b61807ec_3cae_11e7_8c51_109add6da4a2row9_col1" class="data row9 col1" >red</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### ③ Different user_ids are randomly assigned

# %%
pp(
    n_different_users(choose_color_assignment_phase_1, n=10, key='phase1')
)
# Out:
# <style  type="text/css" >
#     #T_b61dcfe2_3cae_11e7_860d_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row0_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row1_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row2_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row3_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row4_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row5_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row6_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row7_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row8_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b61dcfe2_3cae_11e7_860d_109add6da4a2row9_col1 {
#             color:  blue;
#              background-color:  blue;
#         }</style>
# <table id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >user_id</th>
#         <th class="col_heading level0 col1" >phase1</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row0" >0</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row0_col0" class="data row0 col0" >0</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row0_col1" class="data row0 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row1" >1</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row1_col0" class="data row1 col0" >1</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row1_col1" class="data row1 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row2" >2</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row2_col0" class="data row2 col0" >2</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row2_col1" class="data row2 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row3" >3</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row3_col0" class="data row3 col0" >3</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row3_col1" class="data row3 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row4" >4</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row4_col0" class="data row4 col0" >4</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row4_col1" class="data row4 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row5" >5</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row5_col0" class="data row5 col0" >5</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row5_col1" class="data row5 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row6" >6</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row6_col0" class="data row6 col0" >6</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row6_col1" class="data row6 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row7" >7</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row7_col0" class="data row7 col0" >7</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row7_col1" class="data row7 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row8" >8</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row8_col0" class="data row8 col0" >8</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row8_col1" class="data row8 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2" class="row_heading level0 row9" >9</th>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row9_col0" class="data row9 col0" >9</td>
#         <td id="T_b61dcfe2_3cae_11e7_860d_109add6da4a2row9_col1" class="data row9 col1" >blue</td>
#     </tr></tbody>
# </table>

# %%
pp(
    n_different_users(choose_color_assignment_phase_2, n=10, key='phase2')
)
# Out:
# <style  type="text/css" >
#     #T_b623c438_3cae_11e7_99cd_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row0_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row1_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row2_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row3_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row4_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row5_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row6_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row7_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row8_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b623c438_3cae_11e7_99cd_109add6da4a2row9_col1 {
#             color:  blue;
#              background-color:  blue;
#         }</style>
# <table id="T_b623c438_3cae_11e7_99cd_109add6da4a2" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >user_id</th>
#         <th class="col_heading level0 col1" >phase2</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row0" >0</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row0_col0" class="data row0 col0" >0</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row0_col1" class="data row0 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row1" >1</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row1_col0" class="data row1 col0" >1</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row1_col1" class="data row1 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row2" >2</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row2_col0" class="data row2 col0" >2</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row2_col1" class="data row2 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row3" >3</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row3_col0" class="data row3 col0" >3</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row3_col1" class="data row3 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row4" >4</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row4_col0" class="data row4 col0" >4</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row4_col1" class="data row4 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row5" >5</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row5_col0" class="data row5 col0" >5</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row5_col1" class="data row5 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row6" >6</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row6_col0" class="data row6 col0" >6</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row6_col1" class="data row6 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row7" >7</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row7_col0" class="data row7 col0" >7</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row7_col1" class="data row7 col1" >red</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row8" >8</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row8_col0" class="data row8 col0" >8</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row8_col1" class="data row8 col1" >blue</td>
#     </tr>    <tr>
#         <th id="T_b623c438_3cae_11e7_99cd_109add6da4a2" class="row_heading level0 row9" >9</th>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row9_col0" class="data row9 col0" >9</td>
#         <td id="T_b623c438_3cae_11e7_99cd_109add6da4a2row9_col1" class="data row9 col1" >blue</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# ### ④ The proportion of user_ids that see red and blue is the correct proportion

# %%
n_different_users(choose_color_assignment_phase_1, n=10000, key='phase1').groupby('phase1').count()
# Out:
#         user_id
# phase1
# blue       2003
# red        7997

# %%
n_different_users(choose_color_assignment_phase_2, n=10000, key='phase2').groupby('phase2').count()
# Out:
#         user_id
# phase2
# blue       4954
# red        5046

# %% [markdown]
# ### Ⓐ Devices that see blue in phase 1 should continue to see it in phase 2
#
# This is like the usual graph, but shows phase1 and phase2 side-by-side.
# Anyone who saw blue in *phase 1* should also see it in *phase 2*.

# %%
pp(
    pd.merge(
        n_different_users(choose_color_assignment_phase_1, n=100, key='phase1'), 
        n_different_users(choose_color_assignment_phase_2, n=100, key='phase2'), 
        on='user_id'
    )
)
# Out:
# <style  type="text/css" >
#     #T_b65d62ec_3cae_11e7_861a_109add6da4a2 .row_heading, .blank {
#           display: none;;
#     }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row0_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row0_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row1_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row1_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row2_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row2_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row3_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row3_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row4_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row4_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row5_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row5_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row6_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row6_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row7_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row7_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row8_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row8_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row9_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row9_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row10_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row10_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row11_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row11_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row12_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row12_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row13_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row13_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row14_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row14_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row15_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row15_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row16_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row16_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row17_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row17_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row18_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row18_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row19_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row19_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row20_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row20_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row21_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row21_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row22_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row22_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row23_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row23_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row24_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row24_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row25_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row25_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row26_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row26_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row27_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row27_col2 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row28_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row28_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row29_col1 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row29_col2 {
#             color:  red;
#              background-color:  red;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row30_col1 {
#             color:  blue;
#              background-color:  blue;
#         }    #T_b65d62ec_3cae_11e7_861a_109add6da4a2row30_col2 {
#             color:  blue;
#              backgrou

# %% [markdown]
# To summarize this, I can count how many saw each color in the two phases.
# I should watch out for phase 1 blue to phase 2 red, since that would break this requirement.

# %%
pd.merge(
        n_different_users(choose_color_assignment_phase_1, n=10000, key='phase1'), 
        n_different_users(choose_color_assignment_phase_2, n=10000, key='phase2'), 
        on='user_id'
    ).groupby(['phase1', 'phase2']).count()
# Out:
#                user_id
# phase1 phase2
# blue   blue       2003
# red    blue       2951
#        red        5046

# %% [markdown]
# # Summary
#
# In this notebook, I extended it to use assignment groups, so it could support experiment rollout.
#
# # Next
#
# That's it! If you're interested in learning more about assignment, here are a few papers:
#
#  - *Designing and Deploying Online Field Experiments* (Bakshy et al). Open sourced! http://facebook.github.io/planout/
#  - *Controlled experiments on the web: survey and practical guide* (Kohavi et al)
#  - *Overlapping Experiment Infrastructure: More, Better, Faster Experimentation* (Tang et al)
#  - *From Infrastructure to Culture: A/B Testing Challenges in Large Scale Social Networks* (Xu et al)

# %% [markdown]
# # TOC
# - **[0. Introduction](0.Introduction.ipynb)**: What a good `choose_color_assignment` function looks like.
# - **[1. Experimental Units](1.ExperimentalUnits.ipynb)**: What happens when I don't pay attention to experimental units.
# - **[2. Deterministic Assignment](2.DeterministicAssignment.ipynb)**: What it looks like to deterministically assign
# - **[3. Scaling](3.Scaling.ipynb)**: How not to run two experiments at the same time.
# - **[4. Rollout](4.Rollout.ipynb)**: How to gradually show users a new experiment.
